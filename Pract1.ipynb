# %%
import numpy as np

# %%
#Задание 1
#Даны вектора x = (1,1), y = (2, 0) и z = (0,2)
#Изобразить вектора на экране
x=np.array([1,1])
y=np.array([2,0])
z=np.array([0,2])

# %%
import matplotlib.pyplot as plt

# %%
plt.figure()
plt.plot(x[0], x[1], '1')
plt.plot(y[0], y[1], '1')
plt.plot(z[0], z[1], '1')
plt.grid()

# %%
plt.plot([1,1])
plt.plot([2,0])
plt.plot([0,2])
plt.show()

# %%
# Задание 2
# Изобразить точку x + y + z
x=np.array([1,1])
y=np.array([2,0])
z=np.array([0,2])
m=x+y+z
print(m)
# Out:
# [3 3]

# %%
plt.figure()
plt.plot(m[0], m[1], '1')
plt.grid()

# %%
# Задание 3
# Найти угол между векторами x и y
x=np.array([1,1])
y=np.array([2,0])
#xy=np.dot(x,y)
#aLenght = np.linalg.norm(x)
#bLenght = np.linalg.norm(y)
#coss=xy/ (aLenght * bLenght)

def cosine (x,y):
    aLenght = np.linalg.norm(x)
    bLenght = np.linalg.norm(y)
    return np.arccos(np.dot(x,y)/ (aLenght * bLenght))
cosine(x,y)*180/np.pi
# Out:
# 45.00000000000001
